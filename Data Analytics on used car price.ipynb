# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df1=pd.read_csv(r"D:\datasets\used car price prediction\car_data.csv")

# %%
df1.head()
# Out:
#                 Model  Selling Price  Kilometers Driven  Year        Owner  \
# 0  MarutiWagonR1.0LXI         312165              82238  2014  First Owner
# 1     ToyotaEtiosLiva         313799              30558  2013  First Owner
# 2       MarutiAlto800         295999              22164  2018  First Owner
# 3         MarutiSwift         435199              30535  2013  First Owner
# 4     MarutiWagonR1.0         289099              15738  2013  First Owner
#
#       Fuel Type Transmission   Insurance  Car Condition
# 0  Petrol + CNG       MANUAL     Expired            4.2
# 1        Petrol       MANUAL  12-09-2021            4.4
# 2        Petrol       MANUAL  01-12-2020            4.8
# 3        Diesel       MANUAL        Comp            4.3
# 4        Petrol       MANUAL  11-08-2021            4.3

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2237 entries, 0 to 2236
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Model              2237 non-null   object
#  1   Selling Price      2237 non-null   int64
#  2   Kilometers Driven  2237 non-null   int64
#  3   Year               2237 non-null   int64
#  4   Owner              2237 non-null   object
#  5   Fuel Type          2237 non-null   object
#  6   Transmission       2237 non-null   object
#  7   Insurance          2223 non-null   object
#  8   Car Condition      2237 non-null   float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 157.4+ KB

# %%
df1['Model'].nunique()
# Out:
# 434

# %%
df2=pd.read_csv(r"D:\datasets\used car price prediction\model_data.csv")

# %%
df2.head()
# Out:
#                              Model Current Price
# 0  HyundaiElitei20Sportz(O)1.4CRDi  Rs.7.69 Lakh
# 1       MarutiErtigaZXISMARTHYBRID  Rs.9.27 Lakh
# 2            MarutiVitaraBrezzaLDI   Rs.7,62,742
# 3     FordEcosport1.5TITANIUMTIVCT  Rs.7.64 Lakh
# 4       HyundaiVernaFLUIDIC1.4CRDI   Rs.9,99,900

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 434 entries, 0 to 433
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Model          434 non-null    object
#  1   Current Price  433 non-null    object
# dtypes: object(2)
# memory usage: 6.9+ KB

# %%
df=pd.merge(df1,df2, on='Model', how='outer')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2237 entries, 0 to 2236
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Model              2237 non-null   object
#  1   Selling Price      2237 non-null   int64
#  2   Kilometers Driven  2237 non-null   int64
#  3   Year               2237 non-null   int64
#  4   Owner              2237 non-null   object
#  5   Fuel Type          2237 non-null   object
#  6   Transmission       2237 non-null   object
#  7   Insurance          2223 non-null   object
#  8   Car Condition      2237 non-null   float64
#  9   Current Price      2235 non-null   object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 192.2+ KB

# %%
df[['Current Price']]
# Out:
#       Current Price
# 0      Rs.4.65 Lakh
# 1      Rs.4.65 Lakh
# 2      Rs.4.65 Lakh
# 3      Rs.4.65 Lakh
# 4      Rs.4.65 Lakh
# ...             ...
# 2232   Rs.4.78 Lakh
# 2233  Rs.11.97 Lakh
# 2234   Rs.8.64 Lakh
# 2235       7,22,198
# 2236   Rs.3.32 Lakh
#
# [2237 rows x 1 columns]

# %%
replace_dict = {'Rs.': '', 'Lakh': ''}
replace_dict2 = {',':''}
df['Current Price'] = df['Current Price'].replace(replace_dict, regex=True)
df['Current Price'] = df['Current Price'].replace(replace_dict2, regex=True)
df['Current Price'] = df['Current Price'].astype(float).multiply(100000)

# %%
df.isnull().sum()
# Out:
# Model                 0
# Selling Price         0
# Kilometers Driven     0
# Year                  0
# Owner                 0
# Fuel Type             0
# Transmission          0
# Insurance            14
# Car Condition         0
# Current Price         2
# dtype: int64

# %%
df[df['Current Price']<1]
# Out:
#                               Model  Selling Price  Kilometers Driven  Year  \
# 1371  VolkswagenPoloCOMFORTLINE1.2L         272299              45711  2010
# 1372  VolkswagenPoloCOMFORTLINE1.2L         256399              63748  2013
# 1373  VolkswagenPoloCOMFORTLINE1.2L         604106              27276  2017
# 1374  VolkswagenPoloCOMFORTLINE1.2L         317999              69745  2013
# 1375  VolkswagenPoloCOMFORTLINE1.2L         443699              60295  2016
# 1376  VolkswagenPoloCOMFORTLINE1.2L         380699             101779  2016
# 1377  VolkswagenPoloCOMFORTLINE1.2L         365299              56244  2013
# 1378  VolkswagenPoloCOMFORTLINE1.2L         355530              66519  2016
# 1379  VolkswagenPoloCOMFORTLINE1.2L         302899              40836  2012
# 1380  VolkswagenPoloCOMFORTLINE1.2L         581899              15426  2017
# 1381  VolkswagenPoloCOMFORTLINE1.2L         193099              61082  2012
# 1408          MarutiSwiftDzireLDIBS         340899             123363  2014
# 1409          MarutiSwiftDzireLDIBS         305199             122165  2013
# 1410          MarutiSwiftDzireLDIBS         303599             154599  2014
# 1411          MarutiSwiftDzireLDIBS         318999              67776  2012
# 1412          MarutiSwiftDzireLDIBS         344698              67411  2013
# 1590      SkodaSuperbELEGANCE1.8TSI         433399              84474  2012
# 1591      SkodaSuperbELEGANCE1.8TSI         351799              76434  2012
# 1759     VolkswagenPoloHIGHLINE1.5L         592599              59325  2015
# 1760     VolkswagenPoloHIGHLINE1.5L         496799              66126  2015
# 1761     VolkswagenPoloHIGHLINE1.5L         367499              86855  2015
# 1762     VolkswagenPoloHIGHLINE1.5L         550699              68093  2015
# 2017       ToyotaInnovaCrysta2.4GX8        1545999              38288  2019
# 2132     SkodaLauraELEGANCE2.0TDICR         307499             187692  2011
# 2157       ToyotaInnovaCrysta2.4VX8        1457099             183456  2017
# 2158       ToyotaInnovaCrysta2.4VX8        1485599             119373  2016
# 2221       ToyotaInnovaCrysta2.4GX7        1395599              64712  2017
# 2222       SkodaRapidELEGANCE1.6TDI         411499             120240  2012
#
#              Owner Fuel Type Transmission   Insurance  Car Condition  \
# 1371   First Owner    Petrol       MANUAL  15-01-2022            4.5
# 1372   First Owner    Petrol       MANUAL  28-06-2021            4.0
# 1373   First Owner    Petrol       MANUAL  11-10-2020            4.6
# 1374   First Owner    Petrol       MANUAL  29-07-2021            4.4
# 1375  Second Owner    Petrol       MANUAL  24-11-2021            4.3
# 1376   First Owner    Petrol       MANUAL  05-12-2020            4.3
# 1377   Third Owner    Diesel       MANUAL     Expired            3.9
# 1378  Second Owner    Petrol       MANUAL     Expired            4.3
# 1379   First Owner    Petrol       MANUAL     Expired            3.9
# 1380   First Owner    Petrol       MANUAL  11-04-2021            4.7
# 1381   First Owner    Petrol       MANUAL     Expired            4.2
# 1408  Second Owner    Diesel       MANUAL  27-08-2021            4.2
# 1409   First Owner    Diesel       MANUAL  25-05-2021            4.3
# 1410   First Owner    Diesel       MANUAL  26-02-2021            4.4
# 1411  Second Owner    Diesel       MANUAL  23-03-2021            4.1
# 1412   First Owner    Diesel       MANUAL     Expired            4.2
# 1590   Third Owner    Petrol    AUTOMATIC  14-03-2021            4.2
# 1591  Second Owner    Petrol       MANUAL     Expired            3.9
# 1759   First Owner    Diesel       MANUAL  22-07-2021            4.4
# 1760   First Owner    Diesel       MANUAL  21-06-2021            4.2
# 1761   First Owner    Diesel       MANUAL     Expired            4.3
# 1762  Second Owner    Diesel       MANUAL     Expired            4.3
# 2017   First Owner    Diesel       MANUAL  19-03-2021            4.7
# 2132   Third Owner    Diesel    AUTOMATIC  26-03-2021            4.0
# 2157   First Owner    Diesel       MANUAL  18-01-2022            4.4
# 2158   First Owner    Diesel       MANUAL  09-09-2021            4.5
# 2221  Second Owner    Diesel       MANUAL  09-06-2021            4.6
# 2222   First Owner    Diesel       MANUAL  07-02-2021            3.9
#
#       Current Price
# 1371            0.0
# 1372            0.0
# 1373            0.0
# 1374            0.0
# 1375            0.0
# 1376            0.0
# 1377            0.0
# 1378            0.0
# 1379            0.0
# 1380            0.0
# 1381            0.0
# 1408            0.0
# 1409            0.0
# 1410            0.0
# 1411            0.0
# 1412            0.0
# 1590            0.0
# 1591            0.0
# 1759            0.0
# 1760            0.0
# 1761            0.0
# 1762            0.0
# 2017            0.0
# 2132            0.0
# 2157            0.0
# 2158            0.0
# 2221            0.0
# 2222            0.0

# %%
df['Current Price'] = df['Current Price'].fillna(df['Current Price'].mode().iloc[0])

# %%
df.loc[df['Current Price'] < 1, 'Current Price'] =df[df['Current Price'] < 1]['Current Price'].replace(0, df['Current Price'].median())

# %%
df['Year'].value_counts()
# Out:
# 2012    314
# 2013    275
# 2014    252
# 2015    252
# 2017    212
# 2016    196
# 2011    179
# 2018    164
# 2010    137
# 2009     88
# 2019     82
# 2008     53
# 2007     23
# 2020      8
# 2006      2
# Name: Year, dtype: int64

# %%
from datetime import date
year = date.today().year
df['Age'] = year - df['Year']

# %%
df['Transmission'].unique()
# Out:
# array(['MANUAL', 'MH12', 'TS07', 'KA01', 'MH05', 'DL5C', 'DL9C', 'MH04',
#        'TS08', 'AUTOMATIC', 'UP14', 'UP32', 'HR03', 'MH01', 'DL2C',
#        'KA05', 'KA50', 'KA53', 'DL12', 'DL11', 'GJ27', 'TN12', 'TN02',
#        'HR26', 'MH03', 'MH47', 'TS09', 'RJ14', 'TN06', 'MH43', 'DL4C',
#        'KA02', 'MH02', 'RJ45', 'DL3C', 'TN22', 'KA04', 'MH46', 'KA51',
#        'PB91', 'DL8C', 'GJ18', 'HR51', 'DL10', 'HR29', 'KA03', 'DL14',
#        'GJ05', 'GJ01', 'PB10', 'MH14', 'UP78', 'GJ06', 'Ch01', 'HR05',
#        'HR12', 'DL1C', 'PB11'], dtype=object)

# %%
df['Transmission'].value_counts()
# Out:
# MANUAL       1909
# AUTOMATIC     170
# MH02            9
# HR26            9
# DL4C            8
# MH12            8
# KA05            7
# MH04            6
# DL12            6
# MH03            6
# KA01            5
# MH01            5
# HR51            4
# KA51            4
# DL3C            4
# KA03            4
# MH47            4
# MH43            4
# DL5C            4
# KA50            4
# RJ14            3
# TS07            3
# DL8C            3
# KA04            3
# KA53            3
# GJ27            3
# MH14            2
# DL2C            2
# MH05            2
# UP32            2
# UP14            2
# KA02            2
# TS08            2
# HR03            1
# GJ05            1
# GJ01            1
# PB10            1
# HR05            1
# UP78            1
# GJ06            1
# Ch01            1
# HR12            1
# DL1C            1
# DL14            1
# GJ18            1
# HR29            1
# DL10            1
# TS09            1
# TN12            1
# PB91            1
# DL11            1
# MH46            1
# TN02            1
# TN22            1
# DL9C            1
# RJ45            1
# TN06            1
# PB11            1
# Name: Transmission, dtype: int64

# %%
df['Transmission'] = np.where(df['Transmission'] != 'AUTOMATIC', 'MANUAL', df['Transmission'])
df['Transmission']
# Out:
# 0       MANUAL
# 1       MANUAL
# 2       MANUAL
# 3       MANUAL
# 4       MANUAL
#          ...
# 2232    MANUAL
# 2233    MANUAL
# 2234    MANUAL
# 2235    MANUAL
# 2236    MANUAL
# Name: Transmission, Length: 2237, dtype: object

# %%
df['Insurance'].value_counts()
# Out:
# Expired              248
# Comp                  64
# Zero_Dep              61
# Third_party           25
# Insurance Expired     16
#                     ...
# 06-01-2023             1
# 12-09-2022             1
# 15-02-2022             1
# 11-01-2022             1
# 20-11-2020             1
# Name: Insurance, Length: 473, dtype: int64

# %%
df['Insurance'].unique()
# Out:
# array(['Expired', '26-07-2021', '18-09-2021', '25-05-2021', '15-10-2021',
#        '02-02-2021', '28-07-2021', '22-11-2022', '20-07-2021', 'Comp',
#        '27-01-2021', '18-11-2021', '14-04-2021', '16-08-2021',
#        '10-09-2020', '06-05-2021', '11-06-2021', '27-09-2021',
#        '08-10-2020', '09-10-2021', '02-08-2021', '29-05-2021',
#        '01-02-2021', '10-08-2021', '15-01-2021', '04-05-2021',
#        '31-01-2022', '11-09-2021', '14-10-2021', '24-02-2021',
#        '20-12-2021', '27-08-2021', '04-11-2021', '08-03-2021',
#        '22-10-2021', '14-02-2021', '04-04-2021', '05-02-2021',
#        '15-07-2021', '12-09-2021', '23-07-2021', '17-11-2021',
#        '17-06-2021', '30-05-2021', '05-09-2020', '30-06-2021',
#        '27-07-2021', '20-06-2021', '27-11-2021', '17-05-2021',
#        '01-12-2020', '17-04-2021', '29-10-2021', '08-04-2021',
#        '15-05-2021', '11-12-2021', '15-02-2022', '01-11-2020',
#        '31-01-2021', '25-04-2021', '3rd Party', '12-09-2022',
#        '06-01-2023', '29-12-2022', '21-08-2021', '07-03-2020',
#        '30-12-2022', '16-06-2021', '23-12-2020', '23-01-2022',
#        '29-12-2020', '18-08-2020', '16-09-2021', '16-12-2020',
#        '06-10-2021', '31-12-2020', '05-02-2022', '25-06-2021',
#        '11-10-2021', '10-02-2021', '12-08-2021', '25-01-2021',
#        '15-03-2021', '03-03-2023', '06-12-2020', '06-01-2022',
#        '08-11-2021', '25-12-2021', '27-03-2022', '18-12-2021',
#        '20-02-2022', '11-10-2020', '05-12-2020', 'Comprehensive',
#        '31-05-2021', '03-12-2021', '17-01-2021', '01-09-2021',
#        '08-02-2022', '02-08-2022', '03-10-2021', '12-01-2021',
#        '04-06-2021', '29-08-2022', '08-12-2020', '17-12-2021',
#        '12-01-2022', '19-02-2020', '02-10-2021', '07-12-2020',
#        '07-04-2021', '16-01-2022', '28-12-2020', '17-12-2020',
#        '15-08-2021', '07-11-2020', '07-06-2021', '07-01-2023',
#        '30-03-2022', '27-05-2021', '08-07-2020', '04-12-2020',
#        '26-11-2020', '28-11-2020', '21-12-2020', '04-01-2022',
#        '05-12-2021', '13-12-2020', '08-07-2021', '02-08-2020',
#        '30-09-2020', '13-02-2021', '13-01-2021', '03-01-2022',
#        '09-06-2021', '18-03-2022', '10-09-2021', '13-06-2020',
#        '05-08-2020', '29-10-2022', '01-02-2022', '28-09-2020',
#        '20-07-2020', '20-11-2020'], dtype=object)

# %%
df['Insurance'] = df['Insurance'].fillna('Not Expired')
df['Insurance'] = df['Insurance'].replace('Insurance Expired', 'Expired')
remaining_values = set(df['Insurance'].unique()) - {'Expired', 'Not Expired'}
df['Insurance'] = df['Insurance'].replace(remaining_values, 'Not Expired')

# %%
df = df.drop('Year', axis=1)

# %%
df.head()
# Out:
#                 Model  Selling Price  Kilometers Driven         Owner  \
# 0  MarutiWagonR1.0LXI         312165              82238   First Owner
# 1  MarutiWagonR1.0LXI         242499              88514  Second Owner
# 2  MarutiWagonR1.0LXI         381699              29735  Second Owner
# 3  MarutiWagonR1.0LXI         181999             153709   First Owner
# 4  MarutiWagonR1.0LXI         239499              88691  Second Owner
#
#       Fuel Type Transmission    Insurance  Car Condition  Current Price  Age
# 0  Petrol + CNG       MANUAL      Expired            4.2       465000.0   10
# 1  Petrol + CNG       MANUAL  Not Expired            4.4       465000.0    9
# 2  Petrol + CNG       MANUAL  Not Expired            4.3       465000.0    7
# 3  Petrol + CNG       MANUAL  Not Expired            4.1       465000.0   11
# 4  Petrol + CNG       MANUAL  Not Expired            4.4       465000.0   12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2237 entries, 0 to 2236
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Model              2237 non-null   object
#  1   Selling Price      2237 non-null   int64
#  2   Kilometers Driven  2237 non-null   int64
#  3   Owner              2237 non-null   object
#  4   Fuel Type          2237 non-null   object
#  5   Transmission       2237 non-null   object
#  6   Insurance          2237 non-null   object
#  7   Car Condition      2237 non-null   float64
#  8   Current Price      2237 non-null   float64
#  9   Age                2237 non-null   int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 192.2+ KB

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Age', y='Selling Price', data=df, estimator=sum, hue='Transmission')
plt.title('Total Selling Price by Age and Transmission')
plt.xlabel('Age')
plt.ylabel('Total Selling Price')
# Out:
# Text(0, 0.5, 'Total Selling Price')

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Selling Price'], kde=True)
plt.title('Distribution of Selling Price')
plt.xlabel('Selling Price')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(df['Selling Price'], fill=True)
plt.title('Kernel Density Estimate of Selling Price')
plt.xlabel('Selling Price')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Kilometers Driven', y='Selling Price', data=df)
plt.title('Scatter Plot - Selling Price vs Kilometers Driven')
plt.xlabel('Kilometers Driven')
plt.ylabel('Selling Price')
# Out:
# Text(0, 0.5, 'Selling Price')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Transmission', data=df)
plt.title('Count of Cars by Transmission Type')
plt.xlabel('Transmission Type')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Age', y='Selling Price', data=df, estimator=sum)
plt.title('Sum of Selling Price Age-Wise')
plt.xlabel('Age')
plt.ylabel('Sum of Selling Price')
# Out:
# Text(0, 0.5, 'Sum of Selling Price')

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='Fuel Type', y='Selling Price', data=df)
plt.title('Violin Plot - Distribution of Selling Price by Fuel Type')
plt.xlabel('Fuel Type')
plt.ylabel('Selling Price')
# Out:
# Text(0, 0.5, 'Selling Price')

# %%
plt.figure(figsize=(10, 6))
sns.swarmplot(x='Owner', y='Selling Price', data=df)
plt.title('Swarm Plot - Selling Price by Owner')
plt.xlabel('Owner')
plt.ylabel('Selling Price')
# Out:
# Text(0, 0.5, 'Selling Price')

# %%
plt.figure(figsize=(8, 8))
fuel_type_distribution = df['Fuel Type'].value_counts()
plt.pie(fuel_type_distribution, labels=fuel_type_distribution.index, autopct='%1.1f%%')
plt.title('Distribution of Fuel Types')
# Out:
# Text(0.5, 1.0, 'Distribution of Fuel Types')

# %%
plt.figure(figsize=(14, 8))
sns.stripplot(x='Transmission', y='Selling Price', hue='Fuel Type', data=df, jitter=True, dodge=True)
plt.title('Strip Plot - Selling Price by Transmission and Fuel Type')
plt.xlabel('Transmission')
plt.ylabel('Selling Price')
plt.legend(title='Fuel Type')

# %%
plt.figure(figsize=(12, 6))
sns.boxenplot(x='Age', y='Selling Price', hue='Fuel Type', data=df)
plt.title('Boxen Plot - Selling Price by Age and Fuel Type')
plt.xlabel('Age')
plt.ylabel('Selling Price')
plt.legend(title='Fuel Type')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Owner', hue='Transmission', data=df)
plt.title('Count of Cars by Owner and Transmission')
plt.xlabel('Owner')
plt.ylabel('Count')
plt.legend(title='Transmission')

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='Age', y='Kilometers Driven', data=df)
plt.title('Trends in Kilometers Driven over Age')
plt.xlabel('Age')
plt.ylabel('Kilometers Driven')
# Out:
# Text(0, 0.5, 'Kilometers Driven')
